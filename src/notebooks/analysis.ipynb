# %% [markdown]
# # Data Analysis
#
# This notebook is intended for data analysis related to the MCI506 Data Engineering project. It will include various analyses performed on the processed data.

# %%
# Import necessary libraries
import pandas as pd
import numpy as np

# Load processed data
# processed_data = pd.read_csv('../data/processed/your_processed_file.csv')

# Perform analysis
# Example: Display the first few rows of the dataset
# processed_data.head()
